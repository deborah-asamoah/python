# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
myDataFrame = pd.read_csv("AAPL-2016.csv")['Volume']
myDataFrame.plot()
# Out:
# <Axes: >

# %%
myDataFrame = pd.read_csv('AAPL-2016.csv',usecols=['Date','Volume'])
myDataFrame.plot()
