# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_2017 = pd.read_csv("AAPL-2017.csv", usecols=['Date', 'Volume'])
df_2017_array = np.array(df_2017)
df_2017_array
# Out:
# array([['2017-01-03', 28781900],
#        ['2017-01-04', 21118100],
#        ['2017-01-05', 22193600],
#        ['2017-01-06', 31751900],
#        ['2017-01-09', 33561900],
#        ['2017-01-10', 24462100],
#        ['2017-01-11', 27588600],
#        ['2017-01-12', 27086200],
#        ['2017-01-13', 26111900],
#        ['2017-01-17', 34439800],
#        ['2017-01-18', 23713000],
#        ['2017-01-19', 25597300],
#        ['2017-01-20', 32597900],
#        ['2017-01-23', 22050200],
#        ['2017-01-24', 23211000],
#        ['2017-01-25', 32377600],
#        ['2017-01-26', 26337600],
#        ['2017-01-27', 20562900],
#        ['2017-01-30', 30377500],
#        ['2017-01-31', 49201000],
#        ['2017-02-01', 111985000],
#        ['2017-02-02', 33710400],
#        ['2017-02-03', 24507300],
#        ['2017-02-06', 26845900],
#        ['2017-02-07', 38183800],
#        ['2017-02-08', 23004100],
#        ['2017-02-09', 28349900],
#        ['2017-02-10', 20065500],
# ...

# %%
plt.plot(df_2017_array[:, 0], df_2017_array[: ,1])

# %%
date = [datetime.strptime(x,'%Y-%m-%d') for x in df_2017_array[:,0]]
data = pd.Series(np.float64(df_2017_array[:,1]), index=date)
data.plot()
plt.show()
